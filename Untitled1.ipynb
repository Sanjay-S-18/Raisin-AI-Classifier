# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Raisin_Dataset.csv")
df.head()
# Out:
#     Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  87524       442.246011       253.291155      0.819738       90546
# 1  75166       406.690687       243.032436      0.801805       78789
# 2  90856       442.267048       266.328318      0.798354       93717
# 3  45928       286.540559       208.760042      0.684989       47336
# 4  79408       352.190770       290.827533      0.564011       81463
#
#      Extent  Perimeter    Class
# 0  0.758651   1184.040  Kecimen
# 1  0.684130   1121.786  Kecimen
# 2  0.637613   1208.575  Kecimen
# 3  0.699599    844.162  Kecimen
# 4  0.792772   1073.251  Kecimen

# %%
df.Class.value_counts()
# Out:
# Class
# Kecimen    450
# Besni      450
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Area               0
# MajorAxisLength    0
# MinorAxisLength    0
# Eccentricity       0
# ConvexArea         0
# Extent             0
# Perimeter          0
# Class              0
# dtype: int64

# %%
df["Class"] = df["Class"].map(
    {       
        "Kecimen" : 1,
        "Besni" : 0
    }
)

# %%
df.sample(5)
# Out:
#        Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 420   86421       367.170337       300.793986      0.573477       87929
# 501  164782       660.364175       322.620924      0.872536      169000
# 225   79274       406.976226       255.217827      0.778933       81976
# 20    69726       354.176912       252.529208      0.701161       71849
# 728   53373       330.677241       215.701648      0.757959       56639
#
#        Extent  Perimeter  Class
# 420  0.748623   1080.007      1
# 501  0.757758   1654.986      0
# 225  0.708385   1110.378      1
# 20   0.734399   1035.501      1
# 728  0.654281    936.823      0

# %%
x = df.drop(columns = ["Class"])
y = df.Class

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(
    x,
    y,
    random_state=45,
    test_size=0.1
)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(
    n_estimators = 10,
    criterion = "gini",
    max_depth = 100,
    random_state = 42
)

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
model.fit(X_train ,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_train ,y_train) #train error
# Out:
# 1.0

# %%
model.score(X_test ,y_test)
# Out:
# 0.8888888888888888

# %%
from sklearn.metrics import (
                      confusion_matrix,
                      classification_report
)

# %%
from sklearn.metrics import classification_report
report=classification_report(
    y_test,
    y_test
)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        51
#            1       1.00      1.00      1.00        39
#
#     accuracy                           1.00        90
#    macro avg       1.00      1.00      1.00        90
# weighted avg       1.00      1.00      1.00        90

# %%
cm = confusion_matrix(
    y_test,
    y_pred
)
sns.heatmap(
    cm,
    annot = True,
    cmap = "Blues"
)
# Out:
# <Axes: >

# %%
import pickle

# %%
with open("Raisin_Dataset.pkl", "wb") as file:
    pickle.dump(model,file)
